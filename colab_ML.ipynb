# %% [markdown]
# #  colab çalışma ortamı
#
#
# *   tarayıcı kullanılarak python dili yazılır
# *   GPu ve TPU kullanılabilir
# *   ortak çalışma imkanı

# %% [markdown]
# ## merhaba

# %%
print("merhaba dünya")
# Out:
# merhaba dünya

# %% [markdown]
# ## CPU

# %%
# %cat/proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: AuthenticAMD
# cpu family	: 23
# model		: 49
# model name	: AMD EPYC 7B12
# stepping	: 0
# microcode	: 0x1000065
# cpu MHz		: 2249.998
# cache size	: 512 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ht syscall nx mmxext fxsr_opt pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid extd_apicid tsc_known_freq pni pclmulqdq ssse3 fma cx16 sse4_1 sse4_2 movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm cmp_legacy cr8_legacy abm sse4a misalignsse 3dnowprefetch osvw topoext ssbd ibrs ibpb stibp vmmcall fsgsbase tsc_adjust bmi1 avx2 smep bmi2 rdseed adx smap clflushopt clwb sha_ni xsaveopt xsavec xgetbv1 clzero xsaveerptr arat npt nrip_save umip rdpid
# ...

# %% [markdown]
# ## RAM

# %%
# %cat/proc/meminfo
# Out:
# MemTotal:       13333596 kB
# MemFree:        10831104 kB
# MemAvailable:   12545120 kB
# Buffers:           73968 kB
# Cached:          1783472 kB
# SwapCached:            0 kB
# Active:           644728 kB
# Inactive:        1605636 kB
# Active(anon):     356408 kB
# Inactive(anon):      336 kB
# Active(file):     288320 kB
# Inactive(file):  1605300 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               548 kB
# Writeback:             0 kB
# AnonPages:        393020 kB
# Mapped:           205872 kB
# Shmem:               940 kB
# Slab:             160892 kB
# SReclaimable:     122452 kB
# SUnreclaim:        38440 kB
# KernelStack:        3664 kB
# PageTables:         5376 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6666796 kB
# Committed_AS:    2613980 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:           0 kB
# ...

# %% [markdown]
# ## veri bilimi
#
# *   numpy
# *   matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y=50+np.random.randn(50)
x=[x  for x in range(len(y))]
plt.plot(x,y,"*")
plt.fill_between(x,y,45,where=(y>45),facecolor="y",alpha=0.6)
plt.show()

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x='mean(Miles_per_Gallon)',
  y='Origin',
  color='Origin'
)
# Out:
# alt.Chart(...)

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x=alt.X('Miles_per_Gallon', bin=True),
  y='count()',
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## kimlik doğrulama

# %%
from google.colab import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
ls
# Out:
# 'My Drive'/

# %%
pip install keras

# %%
import keras

# %%
# !apt-get install graphviz -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# graphviz is already the newest version (2.40.1-2).
# 0 upgraded, 0 newly installed, 0 to remove and 11 not upgraded.

# %% [markdown]
# ### GPU

# %%
import tensorflow as tf

# %%
print("TF version ",tf.__version__ )
# Out:
# TF version  2.3.0

# %%
import tensorflow_hub as hub

# %%
print("hub version ", hub.__version__)
# Out:
# hub version  0.9.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
print("gpu is ","available" if tf.test.is_gpu_available() else "not available")
# Out:
# WARNING:tensorflow:From <ipython-input-7-b4b3de00340e>:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# gpu is  available

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 10062872167599473993, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 16704005776737091754
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 3801072264673510727
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14640891840
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 1887884486317211024
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"]

# %%
# !ls 'My Drive/colab_derinOgrenme'
# Out:
# CNN.py	colab_ML.ipynb

# %%
# !kill -9 -1

# %%
# !python  'My Drive/colab_derinOgrenme/CNN.py'
# Out:
# 2020-10-29 23:19:04.277242: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-29 23:19:05.659817: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-29 23:19:05.694457: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-29 23:19:05.695044: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-10-29 23:19:05.695089: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !ls
# Out:
# 'My Drive'
