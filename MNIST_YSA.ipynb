# %% [markdown]
# # yapay sinir ağ

# %% [markdown]
# ## mnist verisi yüklemek

# %%
from keras.datasets import mnist
(x_train,y_train),(x_test,y_test)=mnist.load_data()

# %% [markdown]
# ## ysa mimarisi

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
network=Sequential()

# %%
network.add(Dense(512,activation="relu",input_shape=(28*28,)))
network.add(Dense(10,activation="softmax"))

# %% [markdown]
# ## modelin derlenmesi

# %%
network.compile(optimizer="rmsprop",loss="categorical_crossentropy",metrics=["accuracy"])

# %% [markdown]
# ### girişlerin ve etiketlerin hazırlanması

# %%
x_train=x_train.reshape((60000,28*28))
x_train=x_train.astype("float32")/255

x_test=x_test.reshape((10000,28*28))
x_test=x_test.astype("float32")/255

# %%
from keras.utils import to_categorical

# %%
y_train=to_categorical(y_train)
y_test=to_categorical(y_test)

# %% [markdown]
# ### modelin eğitilmesi

# %%
network.fit(x_train,y_train,batch_size=128,epochs=5)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2559 - accuracy: 0.9262
# Epoch 2/5
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1030 - accuracy: 0.9694
# Epoch 3/5
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0678 - accuracy: 0.9800
# Epoch 4/5
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0490 - accuracy: 0.9853
# Epoch 5/5
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0369 - accuracy: 0.9887

# %%
loss,accuracy=network.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0731 - accuracy: 0.9786

# %%
print(loss)
print(accuracy)
# Out:
# 0.07311450690031052
# 0.978600025177002
